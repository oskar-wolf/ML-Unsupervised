# %%
import pandas as pd
from scipy.stats import spearmanr
from datetime import date
import seaborn as sns

# %%
dat = pd.read_csv("data_visitors.csv",delimiter=' ')

# %%
dat
# Out:
#            date  visitors
# 0    2021-01-01      2735
# 1    2021-01-02      2084
# 2    2021-01-03       647
# 3    2021-01-04      1098
# 4    2021-01-05      1778
# ..          ...       ...
# 360  2021-12-27       536
# 361  2021-12-28       277
# 362  2021-12-29       842
# 363  2021-12-30      1163
# 364  2021-12-31      2200
#
# [365 rows x 2 columns]

# %%
#correlate the date and the visitors
spearmanr(dat['date'],dat['visitors'])
# Out:
# SignificanceResult(statistic=0.0010369613036009904, pvalue=0.9842482530265125)

# %%
dat["date"] = pd.to_datetime(dat["date"])

# %%
dat
# Out:
#           date  visitors
# 0   2021-01-01      2735
# 1   2021-01-02      2084
# 2   2021-01-03       647
# 3   2021-01-04      1098
# 4   2021-01-05      1778
# ..         ...       ...
# 360 2021-12-27       536
# 361 2021-12-28       277
# 362 2021-12-29       842
# 363 2021-12-30      1163
# 364 2021-12-31      2200
#
# [365 rows x 2 columns]

# %%
dat["weekday"] = dat["date"].apply(lambda date: date.weekday())

# %%
dat
# Out:
#           date  visitors  weekday
# 0   2021-01-01      2735        4
# 1   2021-01-02      2084        5
# 2   2021-01-03       647        6
# 3   2021-01-04      1098        0
# 4   2021-01-05      1778        1
# ..         ...       ...      ...
# 360 2021-12-27       536        0
# 361 2021-12-28       277        1
# 362 2021-12-29       842        2
# 363 2021-12-30      1163        3
# 364 2021-12-31      2200        4
#
# [365 rows x 3 columns]

# %%
dat["weekend"] = dat["weekday"].apply(lambda weekday : 0 if (weekday < 5) else 1)

# %%
dat
# Out:
#           date  visitors  weekday  weekend
# 0   2021-01-01      2735        4        0
# 1   2021-01-02      2084        5        1
# 2   2021-01-03       647        6        1
# 3   2021-01-04      1098        0        0
# 4   2021-01-05      1778        1        0
# ..         ...       ...      ...      ...
# 360 2021-12-27       536        0        0
# 361 2021-12-28       277        1        0
# 362 2021-12-29       842        2        0
# 363 2021-12-30      1163        3        0
# 364 2021-12-31      2200        4        0
#
# [365 rows x 4 columns]

# %%
spearmanr(dat["weekend"],dat["visitors"])
# Out:
# SignificanceResult(statistic=0.20095637220308932, pvalue=0.00011081519702575257)

# %%
ax = sns.barplot(x="weekend", y="visitors", data=dat)

# %%
dat
# Out:
#           date  visitors  weekday  weekend
# 0   2021-01-01      2735        4        0
# 1   2021-01-02      2084        5        1
# 2   2021-01-03       647        6        1
# 3   2021-01-04      1098        0        0
# 4   2021-01-05      1778        1        0
# ..         ...       ...      ...      ...
# 360 2021-12-27       536        0        0
# 361 2021-12-28       277        1        0
# 362 2021-12-29       842        2        0
# 363 2021-12-30      1163        3        0
# 364 2021-12-31      2200        4        0
#
# [365 rows x 4 columns]
