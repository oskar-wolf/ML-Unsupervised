# %%
import pandas as pd 
from datetime import date

# %%
Table = {'Customer-ID': [1, 2, 3, 4, 5], \
    'Date': ['12-05-2019', '18-08-2018', \
        '05-07-2017', '03-09-2020', '09-07-2018'], \
    'Consumption': [70, 140, 65, 40, 65]}

TDF = pd.DataFrame(data = Table)

# %%
TDF
# Out:
#    Customer-ID        Date  Consumption
# 0            1  12-05-2019           70
# 1            2  18-08-2018          140
# 2            3  05-07-2017           65
# 3            4  03-09-2020           40
# 4            5  09-07-2018           65

# %%
TDF['Date'] = pd.to_datetime(TDF.Date, format="%d-%m-%Y")

# %%
TDF
# Out:
#    Customer-ID       Date  Consumption
# 0            1 2019-05-12           70
# 1            2 2018-08-18          140
# 2            3 2017-07-05           65
# 3            4 2020-09-03           40
# 4            5 2018-07-09           65

# %%
TDF['Year'] = TDF['Date'].dt.year

# %%
TDF['Month'] = TDF['Date'].dt.month

# %%
TDF['quarter'] = TDF['Date'].dt.quarter

# %%
TDF
# Out:
#    Customer-ID       Date  Consumption  Year  Month  quarter
# 0            1 2019-05-12           70  2019      5        2
# 1            2 2018-08-18          140  2018      8        3
# 2            3 2017-07-05           65  2017      7        3
# 3            4 2020-09-03           40  2020      9        3
# 4            5 2018-07-09           65  2018      7        3

# %%
years_diff = date.today().year - TDF['Date'].dt.year
TDF['passed_years'] = years_diff

# %%
months_diff = (date.today().year - \
    TDF['Date'].dt.year) * 12 + \
        date.today().month - \
            TDF['Date'].dt.month

TDF['passed_months'] = months_diff

# %%
TDF
# Out:
#    Customer-ID       Date  Consumption  Year  Month  quarter  passed_years  \
# 0            1 2019-05-12           70  2019      5        2             5
# 1            2 2018-08-18          140  2018      8        3             6
# 2            3 2017-07-05           65  2017      7        3             7
# 3            4 2020-09-03           40  2020      9        3             4
# 4            5 2018-07-09           65  2018      7        3             6
#
#    passed_months
# 0             59
# 1             68
# 2             81
# 3             43
# 4             69

# %%
TDF['day_name'] = TDF['Date'].dt.day_name()

# %%
TDF
# Out:
#    Customer-ID       Date  Consumption  Year  Month  quarter  passed_years  \
# 0            1 2019-05-12           70  2019      5        2             5
# 1            2 2018-08-18          140  2018      8        3             6
# 2            3 2017-07-05           65  2017      7        3             7
# 3            4 2020-09-03           40  2020      9        3             4
# 4            5 2018-07-09           65  2018      7        3             6
#
#    passed_months   day_name
# 0             59     Sunday
# 1             68   Saturday
# 2             81  Wednesday
# 3             43   Thursday
# 4             69     Monday

# %%
TDF['dow'] = pd.to_datetime(TDF['Date']).dt.dayofweek

# %%
TDF
# Out:
#    Customer-ID       Date  Consumption  Year  Month  quarter  passed_years  \
# 0            1 2019-05-12           70  2019      5        2             5
# 1            2 2018-08-18          140  2018      8        3             6
# 2            3 2017-07-05           65  2017      7        3             7
# 3            4 2020-09-03           40  2020      9        3             4
# 4            5 2018-07-09           65  2018      7        3             6
#
#    passed_months   day_name  dow
# 0             59     Sunday    6
# 1             68   Saturday    5
# 2             81  Wednesday    2
# 3             43   Thursday    3
# 4             69     Monday    0

# %%
TDF['weekend'] = TDF['dow'].\
    map(lambda x : 0 if x < 5 else 1)

# %%
TDF
# Out:
#    Customer-ID       Date  Consumption  Year  Month  quarter  passed_years  \
# 0            1 2019-05-12           70  2019      5        2             5
# 1            2 2018-08-18          140  2018      8        3             6
# 2            3 2017-07-05           65  2017      7        3             7
# 3            4 2020-09-03           40  2020      9        3             4
# 4            5 2018-07-09           65  2018      7        3             6
#
#    passed_months   day_name  dow  weekend
# 0             59     Sunday    6        1
# 1             68   Saturday    5        1
# 2             81  Wednesday    2        0
# 3             43   Thursday    3        0
# 4             69     Monday    0        0
